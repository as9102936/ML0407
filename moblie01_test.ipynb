# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urlparse, parse_qs, urlunparse

# %%
r = requests.get("https://www.mobile01.com/topiclist.php?f=689",
                 headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36"})

# %%
html_doc = r.text
html_doc
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="zh-Hant-TW">\n    <head>\n        <meta charset="UTF-8" />\n        <meta http-equiv="X-UA-Compatible" content="ie=edge">\n        <title>OPPO - Mobile01</title>\n        <meta name="HandheldFriendly" content="True">\n        <meta name="MobileOptimized" content="360">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <meta http-equiv="cleartype" content="on">\n        <meta name="title" property="og:title" itemprop="name" content="OPPO - Mobile01" />\n        <meta name="description" property="og:description" itemprop="description" content="想了解新手機功能、同類型產品集評、深度觀點剖析以及有趣 APP 介紹，就來 Mobile01 手機頻道吧！" />\n                <meta name="twitter:image" property="og:image" itemprop="image" content="https://attach2.mobile01.com/images/category/16.jpg">\n        <meta name="google-site-verification" content="yc025e_izefzuvCZl-aTg8EEcSHug0INQkvrd7TQqDw" />\n        <meta property="fb:admins" content="100000081762620" />\n        <meta property="fb:app_id" content="1548610928687358" />\n        <meta property="og:locale" content="zh_TW" />\n                        <meta property="og:image:width" content="800" />\n        <meta property="og:image:height" content="533" />\n        <meta property="og:site_name" content="Mobile01" />\n                        <meta property="og:url" content="https://www.mobile01.com/topiclist.php?f=689">\n        <link rel="canonical" href="https://www.mobile01.com/topiclist.php?f=689" >\n                        <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.mobile01.com/topiclist.php?f=689">\n        <meta name="twitter:url" content="https://www.mobile01.com/topiclist.php?f=689" />\n                <meta name="twitter:card" content="summary" />\n        <meta name="twitter:site" content="@Mobile01Service" />\n        <meta name="twitter:title" content="OPPO - Mobile01" />\n        <meta name="twitter:description" content="想了解新手機功能、同類型產品集評、深度觀點剖析以及有趣 APP 介紹，就來 Mobile01 手機頻道吧！" />\n                <meta name="msapplication-TileImage" content="https://attach2.mobile01.com/images/touch/apple-touch-icon-144x144.png">\n        <meta name="msapplication-TileColor" content="#222222">\n        <link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://attach2.mobile01.com/images/touch/apple-touch-icon-180x180.png">\n        <link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://attach2.mobile01.com/images/touch/apple-touch-icon-152x152.png">\n        <link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://attach2.mobile01.com/images/touch/apple-touch-icon-144x144.png">\n        <link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://attach2.mobile01.com/images/touch/apple-touch-icon-120x120.png">\n        <link rel="apple-touch-icon-precomposed" sizes="114x114" href="https://attach2.mobile01.com/images/touch/apple-touch-icon-114x114.png">\n        <link rel="apple-touch-icon-precomposed" sizes="76x76" href="https://attach2.mobile01.com/images/touch/apple-touch-icon-76x76.png">\n        <link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://attach2.mobile01.com/images/touch/apple-touch-icon-72x72.png">\n        <link rel="apple-touch-icon-precomposed" href="https://attach2.mobile01.com/images/touch/apple-touch-icon-57x57.png">\n        <link rel="shortcut icon" href="https://attach2.mobile01.com/images/touch/apple-touch-icon.png">\n        <link rel="shortcut icon" href="/favicon.ico">\n        <link rel="icon" sizes="192x192" href="https://attach2.mobile01.com/images/touch/touch-icon-192x192.png">\n        <link rel="icon" sizes="128x128" href="https://attach2.mobile01.com/images/touch/touch-icon-128x128.png">\n        <link rel="stylesheet" href="https://attach2.mobile01.com/css/normalize-min.css">\n        <link rel="stylesheet" href="https://attach2.mobile01.com/js/jquery-swiper/css/swiper-min.css">\n        <link rel="stylesheet" href ...

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
# 輸出排版後的 HTML 程式碼
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="zh-Hant-TW">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    OPPO - Mobile01
#   </title>
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="360" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="on" http-equiv="cleartype"/>
#   <meta content="OPPO - Mobile01" itemprop="name" name="title" property="og:title">
#    <meta content="想了解新手機功能、同類型產品集評、深度觀點剖析以及有趣 APP 介紹，就來 Mobile01 手機頻道吧！" itemprop="description" name="description" property="og:description">
#     <meta content="https://attach2.mobile01.com/images/category/16.jpg" itemprop="image" name="twitter:image" property="og:image"/>
#     <meta content="yc025e_izefzuvCZl-aTg8EEcSHug0INQkvrd7TQqDw" name="google-site-verification">
#      <meta content="100000081762620" property="fb:admins">
#       <meta content="1548610928687358" property="fb:app_id">
#        <meta content="zh_TW" property="og:locale">
#         <meta content="800" property="og:image:width"/>
#         <meta content="533" property="og:image:height"/>
#         <meta content="Mobile01" property="og:site_name"/>
#         <meta content="https://www.mobile01.com/topiclist.php?f=689" property="og:url"/>
#         <link href="https://www.mobile01.com/topiclist.php?f=689" rel="canonical"/>
#         <link href="https://m.mobile01.com/topiclist.php?f=689" media="only screen and (max-width: 640px)" rel="alternate"/>
#         <meta content="https://www.mobile01.com/topiclist.php?f=689" name="twitter:url">
#          <meta content="summary" name="twitter:card"/>
#          <meta content="@Mobile01Service" name="twitter:site"/>
#          <meta content="OPPO - Mobile01" name="twitter:title"/>
#          <meta content="想了解新手機功能、同類型產品集評、深度觀點剖析以及有趣 APP 介紹，就來 Mobile01 手機頻道吧！" name="twitter:description"/>
#          <meta content="https://attach2.mobile01.com/images/touch/apple-touch-icon-144x144.png" name="msapplication-TileImage"/>
#          <meta content="#222222" name="msapplication-TileColor"/>
#          <link href="https://attach2.mobile01.com/images/touch/apple-touch-icon-180x180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
#          <link href="https://attach2.mobile01.com/images/touch/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#          <link href="https://attach2.mobile01.com/images/touch/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#          <link href="https://attach2.mobile01.com/images/touch/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#          <link href="https://attach2.mobile01.com/images/touch/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#          <link href="https://attach2.mobile01.com/images/touch/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#          <link href="https://attach2.mobile01.com/images/touch/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#          <link href="https://attach2.mobile01.com/images/touch/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed"/>
#          <link href="https://attach2.mobile01.com/images/touch/apple-touch-icon.png" rel="shortcut icon"/>
#          <link href="/favicon.ico" rel="shortcut icon"/>
#          <link href="https://attach2.mobile01.com/images/touch/touch-icon-192x192.png" rel="icon" sizes="192x192"/>
#          <link href="https://attach2.mobile01.com/images/touch/touch-icon-128x128.png" rel="icon" sizes="128x128"/>
#          <link href="https://attach2.mobile01.com/css/normalize-min.css" rel="stylesheet"/>
#          <link href="https://attach2.mobile01.com/js/jquery-swiper/css/swiper-min.css" rel="stylesheet"/>
#          <link href="https://attach2.mobile01.com/js/jquery-fancybox/jquery-fancybox-min.css" rel="stylesheet"/>
#          <link href="https://attach2.mobile01.com/js/jquery-superfish/superfish.css" rel="stylesheet"/>
#          <link href="https://attach2.mobile01.com/js/jquery-ui-datepicker/css/jquery-ui.min.css" rel="stylesheet"/>
#          <link href="https://attach2.mobile01.com/js/jquery-ui-datepicker/css/jquery-ui.structure.min.css" rel="stylesheet"/>
#          <link href="https://attach2.mobile01.com/js/jquery-ui-datepicker/css/jquery-ui.theme.min.css" rel="stylesheet"/>
#          <link href="https://attach2.mobile01.com/css/layout-min.css" rel="stylesheet"/>
#          <link href="https://attach2.mobile01.com/css/main-min.css" rel="stylesheet"/>
#          <link href="https://attach2.mobile01.com/css/main-dark.css?t=1577635200" rel="stylesheet"/>
#          <style type="text/css">
#           main.l-main {
#             background-color: #f0f0f0;
#             padding: 0px;
#         }
#         .sf-menu a {
#             padding: .75em .88em;
#         }
#         .l-footer__links {
#             border-top: 1px solid #dadada;
#         }
#         .l-footerLinks>li {
#             margin: 0px 20px;
#         }
#         ul.l-footerLinks > li.footer-icon {
#             margin-left: 20px;
#         }
#         .background-side {
#             width: 1330px;
#             margin: 0px auto;
#         }
#         .content-side {
#             width: 1330px;
#             margin: 0px auto;
#             background-color: #fdfdfd;
#             padding-top: 15px;
#             padding-bottom: 60px;
#         }
#         a {
#             cursor: pointer;
#         }
#         .o-logo {
#             margin-top: -5px;
#         }
#         .c-menuLv1__name {
#             padding: 15px;
#         }
#         .o-mainCardDesc {
#             max-height: 3em;
#             height: auto;
#         }
#         .l-signedIn__funs {
#             display: flex;
#             align-items: center;
#         }
#         ul.sf-menu {
#             float: unset;
#         }
#         .sf-menu li {
#             background-color: #ffffff;
#         }
#         .sf-menu li:hover {
#             background-color: #30a651;
#         }
#         .sf-menu a {
#             color: #111;
#             font-size: 15px;
#         }
#         .sf-menu a:hover {
#             color: #ffffff;
#         }
#         .sf-menu ul {
#             min-width: 8em;
#         }
#         .sf-menu > li > ul > li,
#         .sf-menu ul ul li {
#             background-color: #ffffff;
#             border-top: 1px solid #dadada;
#         }
#         .sf-menu ul li a {
#             font-size: 14px;
#         }
#         .ad_fixed {
#             position:sticky;
#             position:-webkit-sticky;
#         }
#         .l-footer__copyright .list {
#             font-size: 14px;
#             display: inline-block;
#             float: left;
#             color: gray;
#         }
#         .l-footer__copyright .list > span > a > img{
#             margin-top: -6px;
#             margin-right: 15px;
#         }
#                 .fixedtop {
#             display: none;
#             width: 100%;
#         }
#         .fixedtop .dialog {
#             margin: 15px;
#             left:0px;
#             right: 0px;
#             top:0px;
#         }
#         .fixedtop .floating {
#             display: flex;
#             -ms-flex-align: center;
#             align-items: center;
#         }
#         .fixedtop .message {
#             font-weight:bold;
#             -ms-flex: 1 1 auto;
#             flex: 1 1 auto;
#         }
#          </style>
#          <style type="text/css">
#           .l-hotCardGroup .u-gapBottom--sm {
#         position: relative;
#     }
#     .l-hotCardGroup .u-gapBottom--sm .l-articleCardDesc span {
#         position: absolute;
#         top: 5px;
#         right: 5px;
#     }
#
#     #fixeddiv {
#         position:fixed;
#         left:0px;
#         bottom:0px;
#         width:100%;
#         background:#E9FCEE;
#         font-size:24px;
#         color:#23803D;
#         letter-spacing:24px;
#         text-align:center;
#         line-height:1.5em;
#         font-weight:bold;
#         z-index:99;
#         opacity:0.8;
#     }
#          </style>
#          <script>
#           dataLayer = [{
#             'member': '92093270-8083-11ea-bb57-3115b9907a00',
#             'memberType':'visitors',
#             'isVIP': 0,
#         }];
#
#         window.dataLayer.push({"dimensionValue":["\u624b\u6a5f","\u624b\u6a5f-Android","\u624b\u6a5f-OPPO"],"category":"\u624b\u6a5f","subcategory":"Android","forum":"OPPO"});
#          </script>
#          <script src="//attach2.mobile01.com/js/gtm.js" type="text/javascript">
#          </script>
#          <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#          </script>
#          <script async="" src="https://attach2.mobile01.com/js/ad/prebid.js?t=1584410400">
#          </script>
#          <script>
#           // Prebid section starts
#             var PREBID_TIMEOUT = 1200;
#             var adUnits = [{code:'div-gpt-ad-1564377728793-0',mediaTypes:{banner:{sizes:[300, 250]}},bids:[{bidder:'appnexus', params:{placementId:13537746}},{bidder:'bridgewell', params:{ChannelID:'CgUxNjU3NRICMTYaBDQ3NjMiCG1vYmlsZTAxKgoIrAIQZBoBNSAB'}},{bidder:'appier', params:{hzid:'HU9QWIOc'}},{bidder:'criteo', params:{networkId:6675}},{bidder:'openx', params:{unit:540960299,delDomain:'mobile01-d.openx.net'}}]},{code:'div-gpt-ad-1564559506807-0',mediaTypes:{banner:{sizes:[[970, 90], [728, 90], [970, 120]]}},bids:[{bidder:'appnexus', params:{placementId:13673659}},{bidder:'bridgewell', params:{ChannelID:'CgUxNjU3NhICMTYaBDQ3NjMiCG1vYmlsZTAxKgoI2AUQWhoBMiAB'}},{bidder:'appier', params:{hzid:'HU9QWzOc'}},{bidder:'criteo', params:{networkId:6675}},{bidder:'openx', params:{unit:540960296,delDomain:'mobile01-d.openx.net'}}]},{code:'div-gpt-ad-1563255979550-0',mediaTypes:{banner:{sizes:[300, 600]}},bids:[{bidder:'appnexus', params:{placementId:13673552}},{bidder:'bridgewell', params:{ChannelID:'CgUxNjU3ORICMTYaBDQ3NjMiCG1vYmlsZTAxKgwIoAEQ2AQaAjIwIAE'}},{bidder:'appier', params:{hzid:'HU9QW9Oc'}},{bidder:'criteo', params:{networkId:6675}},{bidder:'openx', params:{unit:540960302,delDomain:'mobile01-d.openx.net'}}]},{code:'div-gpt-ad-1564377796461-0',mediaTypes:{banner:{sizes:[300, 250]}},bids:[{bidder:'appnexus', params:{placementId:13673551}},{bidder:'bridgewell', params:{ChannelID:'CgUxNjU4MRICMTYaBDQ3NjMiCG1vYmlsZTAxKgwI0AIQmAIaAjQyIAE'}},{bidder:'appier', params:{hzid:'Wtc5W9Op'}},{bidder:'criteo', params:{networkId:6675}}]},{code:'div-gpt-ad-1564377852598-0',mediaTypes:{banner:{sizes:[300, 250]}},bids:[{bidder:'appnexus', params:{placementId:13673550}},{bidder:'bridgewell', params:{ChannelID:'CgUxNjU4MBICMTYaBDQ3NjMiCG1vYmlsZTAxKgsIrAIQ-gEaATkgAQ'}},{bidder:'appier', params:{hzid:'WtcoHIOp'}},{bidder:'criteo', params:{networkId:6675}}]},{code:'div-gpt-ad-1564377961938-0',mediaTypes:{banner:{sizes:[300, 250]}},bids:[{bidder:'appnexus', params:{placementId:13673551}},{bidder:'bridgewell', params:{ChannelID:'CgUxNjU4MRICMTYaBDQ3NjMiCG1vYmlsZTAxKgwI0AIQmAIaAjQyIAE'}},{bidder:'appier', params:{hzid:'Wtc5WIOp'}},{bidder:'criteo', params:{networkId:6675}}]},{code:'div-gpt-ad-1570175379734-0',mediaTypes:{banner:{sizes:[160, 600]}},bids:[{bidder:'appnexus', params:{placementId:13673581}},{bidder:'bridgewell', params:{ChannelID:'CgUxNjU4MhICMTYaBDQ3NjMiCG1vYmlsZTAxKgsIrAIQ2AQaATYgAQ'}},{bidder:'appier', params:{hzid:'HhztHFOc'}},{bidder:'criteo', params:{networkId:6675}},{bidder:'openx', params:{unit:540960300,delDomain:'mobile01-d.openx.net'}}]},{code:'div-gpt-ad-1570175352447-0',mediaTypes:{banner:{sizes:[160, 600]}},bids:[{bidder:'appnexus', params:{placementId:13673581}},{bidder:'bridgewell', params:{ChannelID:'CgUxNzcxOBICMTYaBDQ3NjMiCG1vYmlsZTAxKgwIoAEQ2AQaAjIwIAE'}},{bidder:'appier', params:{hzid:'HhztHIOc'}},{bidder:'criteo', params:{networkId:6675}},{bidder:'openx', params:{unit:540960301,delDomain:'mobile01-d.openx.net'}}]}];
#             var pbjs = pbjs || {};
#             pbjs.que = pbjs.que || [];
#             pbjs.que.push(function() {
#                 pbjs.setConfig({
#                     debug: true,
#                     priceGranularity: "dense",
#                     enableSendAllBids: true, // Default will be `true` as of 1.0
#                     bidderTimeout: 1200, // Default for all requests.
#                     appier: {'farm': 'tw'},
#                     'currency': {
#                         adServerCurrency: 'USD',
#                         granularityMultiplier: 1,
#                         conversionRateFile: 'https://prebid-cdn.apx.appier.net/pw/currency-file@1/latest.json' // override the default rate file
#                     }
#                 });
#
#                 pbjs.addAdUnits(adUnits);
#                 pbjs.requestBids({
#                     bidsBackHandler:initAdserver
#                 });
#             });
#
#             function initAdserver() {
#                 if (pbjs.initAdserverSet) return;
#                 pbjs.initAdserverSet = true;
#                 googletag.cmd.push(function() {
#                     pbjs.que.push(function() {
#                         pbjs.setTargetingForGPTAsync();
#                         googletag.pubads().refresh();
#                     });
#                 });
#             }
#             setTimeout(function() {
#                 initAdserver();
#             }, PREBID_TIMEOUT);
#
#
#             window.googletag = window.googletag || {cmd: []};
#
#             googletag.cmd.push(function() {
#
#         googletag.pubads().disableInitialLoad();
#
#                 googletag.defineSlot('/1019567/new01_熱門大看板', [300, 250], 'div-gpt-ad-1564377728793-0').addService(googletag.pubads());
#                     googletag.defineSlot('/1019567/new01_橫幅Banner', [[970, 90], [728, 90], [970, 120]], 'div-gpt-ad-1564559506807-0').addService(googletag.pubads());
#                     googletag.defineSlot('/1019567/new01_圖文廣告', [[300, 278], [300, 250]], 'div-gpt-ad-1564552698147-0').addService(googletag.pubads()).setCollapseEmptyDiv(true, true);
#                     googletag.defineSlot('/1019567/new01_圖文廣告_2', [[300, 278], [300, 250]], 'div-gpt-ad-1564552755270-0').addService(googletag.pubads()).setCollapseEmptyDiv(true, true);
#                     googletag.defineSlot('/1019567/new01_大摩天', [[300, 600], [160, 600]], 'div-gpt-ad-1563255979550-0').addService(googletag.pubads());
#                     googletag.defineSlot('/1019567/new01_置底看板左', [300, 250], 'div-gpt-ad-1564377796461-0').addService(googletag.pubads());
#                     googletag.defineSlot('/1019567/new01_置底看板中', [300, 250], 'div-gpt-ad-1564377852598-0').addService(googletag.pubads());
#                     googletag.defineSlot('/1019567/new01_置底看板右', [300, 250], 'div-gpt-ad-1564377961938-0').addService(googletag.pubads());
#                     googletag.defineSlot('/1019567/new01_門神_left', [160, 600], 'div-gpt-ad-1570175379734-0').addService(googletag.pubads());
#                     googletag.defineSlot('/1019567/new01_門神_right', [160, 600], 'div-gpt-ad-1570175352447-0').addService(googletag.pubads());
#
#         googletag.pubads().setTargeting('forumtopic_phone', 'f-689');
#
#
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#
#     });
#          </script>
#          <script async="" src="https://static.criteo.net/js/ld/publishertag.js">
#          </script>
#          <script>
#           window.Criteo = window.Criteo || {};
#             window.Criteo.events = window.Criteo.events || [];
#          </script>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PLDRQHX" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="l-container">
#    <div class="fixedtop" tabindex="0">
#     <div aria-describedby="cookieconsent:desc" aria-label="cookieconsent" aria-live="polite" class="dialog floating" role="dialog">
#      <div class="message">
#       為提供您更優質的服務，本網站使用cookies。若您繼續瀏覽網頁，即表示您同意我們的cookies政策。
#       <a class="c-link c-link--gn" href="https://www.mobile01.com/privacy.php" role="button" target="_blank">
#        了解隱私權條款
#       </a>
#      </div>
#      <div class="u-tac cookiebutton">
#       <button aria-label="close cookie message" class="c-btn c-btn--secondary" type="button">
#        我知道了！請關閉提示
#       </button>
#      </div>
#     </div>
#    </div>
#    <header class="l-header">
#     <div class="l-header__main">
#      <div class="l-wrap">
#       <div class="l-header__left">
#        <a href="/">
#         <picture>
#          <!--[if IE 9]><video style="display: none;"><![endif]-->
#          <source media="(min-resolution: 1.3dppx), (-webkit-min-device-pixel-ratio: 3)" srcset="https://attach2.mobile01.com/images/logo/logo_3x.png"/>
#          <source media="(min-resolution: 1.2dppx), (-webkit-min-device-pixel-ratio: 2)" srcset="https://attach2.mobile01.com/images/logo/logo_2x.png"/>
#          <!--[if IE 9]></video><![endif]-->
#          <img alt="Mobile01" class="o-logo" srcset="https://attach2.mobile01.com/images/logo/logo.png"/>
#         </picture>
#        </a>
#        <div class="l-header__group">
#         <div class="c-group" data-group-target="group">
#          <a class="c-group__title" data-group-trigger="group" href="/">
#           討論群組
#          </a>
#          <div class="c-group__options">
#           <a class="c-group__link" href="/marketindex.php">
#            小惡魔市集
#           </a>
#           <a class="c-group__link" href="/tourindex.php">
#            悅遊日本
#           </a>
#           <a class="c-group__link" href="/specialevent.php">
#            活動報導
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="l-header__tools">
#        <div class="l-headerTools">
#         <div class="l-headerTools__search">
#          <div class="c-searchBox is-active">
#           <input class="c-textbox c-searchBox__input" id="keyword" name="keyword" placeholder="搜尋Mobile01" type="text" value=""/>
#           <a class="c-searchBox__search" href="/googlesearch.php">
#           </a>
#          </div>
#         </div>
#         <div class="l-headerTools__login">
#          <a class="c-login" href="/login.php?link=%2Ftopiclist.php%3Ff%3D689">
#           登入/註冊
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="l-header__nav">
#      <nav class="l-menu">
#       <div class="l-wrap">
#        <ul class="c-menuLv1 sf-menu">
#         <li class="c-menuLv1__item">
#          <a class="c-menuLv1__name" data-menu="lv1" href="/">
#           首頁
#          </a>
#          <ul class="c-hotLinks">
#           <li>
#            <a href="/sitemap.php">
#             討論區
#            </a>
#           </li>
#           <li>
#            <a href="/search.php">
#             站內搜尋
#            </a>
#           </li>
#           <li>
#            <a href="/newslist.php">
#             本站新聞
#            </a>
#           </li>
#           <li>
#            <a href="/articles.php">
#             精選文章
#            </a>
#           </li>
#           <li>
#            <a href="/hottopics.php">
#             熱門文章
#            </a>
#           </li>
#           <li>
#            <a href="/newtopics.php">
#             最新文章
#            </a>
#           </li>
#           <li>
#            <a href="/recommendarticle.php">
#             好文英雄
#            </a>
#           </li>
#           <li>
#            <a href="/youtubevideo.php">
#             影片專區
#            </a>
#           </li>
#           <li>
#            <a href="/topicactivity.php">
#             站上活動
#            </a>
#           </li>
#           <li>
#            <a href="/apps.php">
#             APP下載
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id=4">
#           手機
#          </a>
#          <ul>
#           <li>
#            <a href="/forumtopic.php?c=16">
#             手機綜合討論區
#            </a>
#           </li>
#           <li>
#            <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=16&amp;s=20">
#             Android
#            </a>
#            <ul>
#             <li>
#              <a href="javascript:void(0);">
#               台灣品牌
#              </a>
#              <ul>
#               <li>
#                <a href="/topiclist.php?f=564">
#                 Acer
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=588">
#                 Asus
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=624">
#                 GSmart
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=566">
#                 HTC
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=203">
#                 InFocus
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="javascript:void(0);">
#               日韓品牌
#              </a>
#              <ul>
#               <li>
#                <a href="/topiclist.php?f=581">
#                 LG
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=568">
#                 SAMSUNG
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=748">
#                 Sharp
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=569">
#                 Sony / SE
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="javascript:void(0);">
#               歐美品牌
#              </a>
#              <ul>
#               <li>
#                <a href="/topiclist.php?f=722">
#                 BlackBerry
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=565">
#                 Google
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=567">
#                 MOTOROLA
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=742">
#                 Nokia
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="javascript:void(0);">
#               中國品牌
#              </a>
#              <ul>
#               <li>
#                <a href="/topiclist.php?f=629">
#                 Huawei
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=689">
#                 OPPO
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=749">
#                 SUGAR
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=754">
#                 vivo
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=634">
#                 小米手機
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=678">
#                 酷派
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=677">
#                 中興
#                </a>
#               </li>
#               <li>
#                <a href="/topiclist.php?f=679">
#                 聯想
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li>
#              <a href="/topiclist.php?f=586">
#               其他品牌
#              </a>
#             </li>
#             <li>
#              <a href="/topiclist.php?f=423">
#               軟體分享
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=16&amp;s=21">
#           BlackBerry
#          </a>
#          <ul>
#           <li>
#            <a href="/topiclist.php?f=384">
#             BlackBerry
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=680">
#             軟體分享
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=16&amp;s=23">
#           Symbian
#          </a>
#          <ul>
#           <li>
#            <a href="/topiclist.php?f=571">
#             NOKIA
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=572">
#             Samsung
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=573">
#             Sony Ericsson
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=681">
#             其他品牌
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=574">
#             軟體分享
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=16&amp;s=24">
#           Windows Phone
#          </a>
#          <ul>
#           <li>
#            <a href="/topiclist.php?f=221">
#             Acer
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=222">
#             Asus
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=224">
#             HTC
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=437">
#             Garmin-Asus
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=225">
#             GSmart
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=226">
#             HP
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=570">
#             LG
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=631">
#             Nokia
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=450">
#             SAMSUNG
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=575">
#             Sony / SE
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=576">
#             TOSHIBA
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=288">
#             其他品牌
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=129">
#             軟體分享
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=16&amp;s=12">
#           Feature Phone
#          </a>
#          <ul>
#           <li>
#            <a href="/topiclist.php?f=219">
#             Asus
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=175">
#             BenQ
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=349">
#             LG
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=117">
#             MOTOROLA
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=122">
#             NOKIA
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=217">
#             SAMSUNG
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=121">
#             Sony Ericsson
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=165">
#             其他品牌
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a href="javascript:void(0);">
#           手機與資費
#          </a>
#          <ul>
#           <li>
#            <a href="/topiclist.php?f=61">
#             其他智慧型手機
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=62">
#             其他作業系統
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=527">
#             日本手機
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=18">
#             行動通訊與資費
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=738">
#             手機週邊與穿戴裝置
#            </a>
#           </li>
#           <li>
#            <a href="/topiclist.php?f=393">
#             手機消費經驗分享
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </nav>
#     </div>
#    </header>
#   </div>
#  </body>
# </html>
# <li>
#  <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id=5">
#   相機
#  </a>
#  <ul>
#   <li>
#    <a href="/forumtopic.php?c=20">
#     相機綜合討論區
#    </a>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=20&amp;s=16">
#     消費型相機
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=538">
#       Canon
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=245">
#       Casio
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=539">
#       Fujifilm
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=295">
#       Kodak
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=247">
#       Leica
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=540">
#       Nikon
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=541">
#       Olympus
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=542">
#       Panasonic
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=543">
#       Pentax
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=252">
#       Ricoh
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=440">
#       Samsung
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=544">
#       Sigma
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=545">
#       Sony
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=546">
#       消費型相機綜合
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=20&amp;s=17">
#     可換鏡頭相機
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=244">
#       Canon
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=246">
#       Fujifilm
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=183">
#       Leica
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=248">
#       Nikon
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=249">
#       Olympus
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=250">
#       Panasonic
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=251">
#       Pentax
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=556">
#       Samsung
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=755">
#       Samyang
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=253">
#       Sigma
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=254">
#       Sony
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=756">
#       Tamron
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=757">
#       Tokina
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=758">
#       Zeiss
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=547">
#       可換鏡頭相機綜合
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=20&amp;s=18">
#     運動、空拍、攝影機
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=548">
#       Canon
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=759">
#       DJI
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=733">
#       Garmin
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=734">
#       GoPro
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=550">
#       Panasonic
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=552">
#       Sony
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=553">
#       影片後製與剪輯
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=735">
#       運動、空拍、攝影機綜合
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=164">
#     影像器材周邊
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=255">
#     傳統與特殊相機
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=257">
#     攝影觀念及技術
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=256">
#     影像處理與後製
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=395">
#     相機消費經驗分享
#    </a>
#   </li>
#  </ul>
# </li>
# <li>
#  <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id=2">
#   筆電
#  </a>
#  <ul>
#   <li>
#    <a href="/forumtopic.php?c=19">
#     筆電綜合討論區
#    </a>
#   </li>
#   <li>
#    <a href="javascript:void(0);">
#     台灣品牌
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=232">
#       Acer
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=233">
#       Asus
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=235">
#       BenQ
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=724">
#       CJSCOPE
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=725">
#       CLEVO
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=238">
#       GIGABYTE
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=241">
#       MSI
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a href="javascript:void(0);">
#     亞洲品牌
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=237">
#       Fujitsu
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=240">
#       Lenovo
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=760">
#       LG
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=242">
#       Panasonic
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=258">
#       Sony
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=243">
#       Toshiba
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a href="javascript:void(0);">
#     歐美品牌
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=236">
#       DELL
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=239">
#       HP
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=743">
#       Surface
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=605">
#     Android平板電腦
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=163">
#     Windows平板電腦
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=159">
#     其他攜帶型電腦
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=394">
#     筆電消費經驗分享
#    </a>
#   </li>
#  </ul>
# </li>
# <li>
#  <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id=3">
#   電腦
#  </a>
#  <ul>
#   <li>
#    <a href="/forumtopic.php?c=17">
#     電腦綜合討論區
#    </a>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=5">
#     核心組件
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=296">
#       中央處理器
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=488">
#       主機板
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=489">
#       記憶體
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=6">
#     儲存裝置
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=297">
#       硬碟
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=490">
#       SSD固態硬碟
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=491">
#       外接式硬碟盒
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=492">
#       隨身碟與錄音筆
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=493">
#       光碟燒錄
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=494">
#       網路儲存裝置
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=495">
#       其他儲存
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=7">
#     顯示設備
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=298">
#       顯示卡
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=350">
#       電腦螢幕
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=496">
#       電視卡盒
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=8">
#     電腦週邊
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=116">
#       其他電腦週邊
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=351">
#       鍵盤與手寫板
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=497">
#       滑鼠與鍵鼠組
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=498">
#       噴墨印表機
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=499">
#       雷射印表機
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=500">
#       音效裝置
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=9">
#     機殼散熱
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=299">
#       機殼
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=501">
#       電源供應器
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=502">
#       散熱器
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=503">
#       其他電源設備
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=10">
#     網路產品
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=110">
#       基地台與分享器
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=504">
#       網路卡
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=505">
#       網路視訊與電話
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=506">
#       網站與網頁技術
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=507">
#       其他網路設備與技術
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=11">
#     電腦軟體
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=300">
#       作業系統
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=508">
#       電腦安全
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=509">
#       影像處理
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=510">
#       影片播放與轉檔
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=511">
#       文書處理
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=512">
#       其他應用軟體
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=513">
#     品牌電腦與準系統
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=174">
#     自組電腦分享
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=514">
#     其他電腦綜合討論
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=396">
#     電腦組裝訪價消費分享
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=359">
#     Google服務分享
#    </a>
#   </li>
#  </ul>
# </li>
# <li>
#  <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id=15">
#   蘋果
#  </a>
#  <ul>
#   <li>
#    <a href="/forumtopic.php?c=30">
#     蘋果綜合討論區
#    </a>
#   </li>
#   <li>
#    <a href="javascript:void(0);">
#     蘋果軟體綜合
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=482">
#       蘋果軟體
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=626">
#       iPad 軟體
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=627">
#       iPhone 軟體
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=563">
#     iPad
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=383">
#     iPhone
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=479">
#     iPod
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=591">
#     iOS Jailbreak
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=704">
#     Apple TV
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=470">
#     Apple Watch
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=480">
#     Mac桌上型電腦
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=481">
#     Mac筆記型電腦
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=177">
#     蘋果週邊綜合
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=483">
#     蘋果裝置消費經驗分享
#    </a>
#   </li>
#  </ul>
# </li>
# <li>
#  <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id=12">
#   影音
#  </a>
#  <ul>
#   <li>
#    <a href="/forumtopic.php?c=28">
#     影音綜合討論區
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=180">
#     行動影音
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=347">
#     高畫質視界
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=348">
#     發燒音響
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=386">
#     小惡魔影城
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=402">
#     音樂鑑賞室
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=562">
#     其他影音裝置
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=421">
#     小惡魔電視台
#    </a>
#   </li>
#   <li>
#    <a href="/topiclist.php?f=403">
#     影音消費經驗分享
#    </a>
#   </li>
#  </ul>
# </li>
# <li>
#  <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id=6">
#   汽車
#  </a>
#  <ul>
#   <li>
#    <a href="/forumtopic.php?c=21">
#     汽車綜合討論區
#    </a>
#   </li>
#   <li>
#    <a href="javascript:void(0);">
#     歐洲車系
#    </a>
#    <ul>
#     <li>
#      <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=25">
#       德國車系
#      </a>
#      <ul>
#       <li>
#        <a href="/topiclist.php?f=286">
#         德國車系綜合
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=606">
#         Audi
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=275">
#         BMW
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=303">
#         Mercedes Benz
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=369">
#         Opel
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=608">
#         Porsche
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=623">
#         Skoda
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=609">
#         Volkswagen
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=26">
#       英國車系
#      </a>
#      <ul>
#       <li>
#        <a href="/topiclist.php?f=448">
#         英國車系綜合
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=610">
#         Aston Martin
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=727">
#         Bentley
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=603">
#         Jaguar
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=604">
#         Land Rover
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=611">
#         Lotus
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=786">
#         McLaren
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=607">
#         Mini
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=27">
#       法國車系
#      </a>
#      <ul>
#       <li>
#        <a href="/topiclist.php?f=326">
#         法國車系綜合
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=413">
#         Peugeot
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=28">
#       瑞典車系
#      </a>
#      <ul>
#       <li>
#        <a href="/topiclist.php?f=612">
#         Saab
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=339">
#         Volvo
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=29">
#       義大利車系
#      </a>
#      <ul>
#       <li>
#        <a href="/topiclist.php?f=337">
#         義大利車系綜合
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=690">
#         Alfa Romeo
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=613">
#         Ferrari
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=615">
#         Lamborghini
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=614">
#         Maserati
#        </a>
#       </li>
#      </ul>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=30">
#     美國車系
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=617">
#       美國車系綜合
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=260">
#       Ford
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=616">
#       GM車系
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=741">
#       Tesla
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=31">
#     日本車系
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=618">
#       日本車系綜合
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=261">
#       Honda
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=449">
#       INFINITI
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=346">
#       LEXUS
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=276">
#       Mazda
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=262">
#       Mitsubishi
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=263">
#       Nissan
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=336">
#       Subaru
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=277">
#       Suzuki
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=264">
#       Toyota
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=32">
#     韓國車系
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=338">
#       韓國車系綜合
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=585">
#       Hyundai
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=691">
#       KIA
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=33">
#     台灣車系
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=444">
#       LUXGEN
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="javascript:void(0);">
#     汽車周邊
#    </a>
#    <ul>
#     <li>
#      <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=46">
#       汽車行車記錄器
#      </a>
#      <ul>
#       <li>
#        <a href="/topiclist.php?f=621">
#         行車記錄器綜合
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=761">
#         DoD
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=762">
#         GARMIN
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=763">
#         Mio
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=764">
#         PAPAGO
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=21&amp;s=47">
#       汽車GPS
#      </a>
#      <ul>
#       <li>
#        <a href="/topiclist.php?f=228">
#         GARMIN
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=304">
#         HOLUX
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=227">
#         Mio
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=231">
#         PAPAGO
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=305">
#         Panasonic
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=230">
#         TOMTOM
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=688">
#         樂客導航王
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=130">
#         其他品牌
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=519">
#         中國品牌
#        </a>
#       </li>
#       <li>
#        <a href="/topiclist.php?f=520">
#         消費經驗分享
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=620">
#       汽車零組件
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=636">
#       輪圈與輪胎
#      </a>
#     </li>
#    </ul>
#   </li>
#   <li>
#    <a href="javascript:void(0);">
#     汽車話題
#    </a>
#    <ul>
#     <li>
#      <a href="/topiclist.php?f=214">
#       動力研究室
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=278">
#       WRC / F1 賽事討論
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=294">
#       汽機車七嘴八舌
#      </a>
#     </li>
#     <li>
#      <a href="/topiclist.php?f=397">
#       汽車消費經驗分享
#      </a>
# ...
#    <span class="u-tal u-gapRight">
#     粉絲團
#    </span>
#    <span class="u-tal">
#     <a href="https://www.facebook.com/TheMobile01" rel="nofollow noopener noreferrer" target="_blank">
#      <img alt="Mobile01 facebook" height="28" src="https://attach2.mobile01.com/images/icons/social/facebook-footer.svg" width="28"/>
#     </a>
#     <a href="https://twitter.com/Mobile01Service" rel="nofollow noopener noreferrer" target="_blank">
#      <img alt="Mobile01 twitter" height="32" src="https://attach2.mobile01.com/images/icons/social/twitter-footer.svg" width="32"/>
#     </a>
#     <a href="https://www.youtube.com/channel/UCUblDAHVdNEMhQ39ahmPFxA" rel="nofollow noopener noreferrer" target="_blank">
#      <img alt="Mobile01 youtube" height="32" src="https://attach2.mobile01.com/images/icons/social/youtube-footer.svg" width="32"/>
#     </a>
#    </span>
#   </div>
#   <div class="list u-gapRight--max">
#    <span class="u-tal u-gapRight">
#     APP下載
#    </span>
#    <span class="u-tal">
#     <a href="https://apps.apple.com/tw/app/mobile01/id444909583" rel="nofollow noopener noreferrer" target="_blank">
#      <img alt="Mobile01 iOS app" height="32" src="https://attach2.mobile01.com/images/icons/social/apple-footer.svg" width="32"/>
#     </a>
#     <a href="https://play.google.com/store/apps/details?id=com.mobile01.android.forum&amp;hl=zh_TW" rel="nofollow noopener noreferrer" target="_blank">
#      <img alt="Mobile01 Android app" height="32" src="https://attach2.mobile01.com/images/icons/social/android-footer.svg" width="32"/>
#     </a>
#    </span>
#   </div>
#   <div class="list">
#    <span class="u-tal u-gapRight">
#     主題顏色
#    </span>
#    <span class="u-tal">
#     <a class="theme" date-theme="w" href="javascript:void(0);">
#      <img alt="light mode" height="32" src="https://attach2.mobile01.com/images/icons/tools/tool-day.svg" width="32"/>
#     </a>
#     <a class="theme" date-theme="d" href="javascript:void(0);">
#      <img alt="dark mode" height="32" src="https://attach2.mobile01.com/images/icons/tools/tool-dark.svg" width="32"/>
#     </a>
#    </span>
#   </div>
#   <span class="c-copyright u-tar">
#    Copyright © 2020 Yong Sheng Technology Co., Ltd. All rights reserved.
#   </span>
#  </div>
# </footer>
# <script src="https://attach2.mobile01.com/js/modernizr-3_5_0-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-3_2_1-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery.cookie.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-superfish/superfish.min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/picturefill/picturefill-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/picturefill/pf-mutation-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/matchMedia/matchMedia-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-fancyform/lib/jquery-mousewheel.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-fancyform/lib/jquery-hotkeys.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-fancyform/jquery-fancyform.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-scrollToFixed/jquery-scrolltofixed-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-ui-datepicker/js/jquery-ui.min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-ui-datepicker/js/lang/datepicker-zh-TW.js">
# </script>
# <script src="https://attach2.mobile01.com/js/picturefill-background/picturefill-background-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-swiper/js/swiper-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/jquery-fancybox/jquery-fancybox-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/helper-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/plugins-min.js">
# </script>
# <script src="https://attach2.mobile01.com/js/main.js?1566259200">
# </script>
# <script src="https://attach2.mobile01.com/js/public/public.js?t=1566795600">
# </script>
# <script>
#  $(function() {
#                 picturefill();
#
#                 jQuery('ul.sf-menu').superfish({
#                     delay: 0,
#                     cssArrows: false,
#                     onBeforeShow : addMenu
#                 });
#
#                 $(document).on("click", "ul.c-dropdown__select", function() {
#                     if ($(this).hasClass('ui-datepicker-select')) {
#                         var index = ($(this).index() == 1) ? 'ui-datepicker-month' : 'ui-datepicker-year';
#                         var value = $(this).parent().find("select."+index+" option:selected").html();
#                     } else {
#                         var value = $(this).parent().find("select option:selected").html();
#                     }
#                     var h = $(this).find("li").height();
#                     var ul = $(this).find("ul.transformSelectDropdown");
#                     var height = ul.find('li:contains("'+value+'")').index() * h;
#                     if (ul.css('display') == 'block') {
#                         ul.scrollTop(height);
#                     }
#                 });
#
#                 var keyword_param = "q";
#                 if ($(".c-searchBox a").is("#market_search")) {
#                     var keyword_param = "k";
#                 }
#
#                 $('#keyword').keypress(function(event) {
#                     if (event.keyCode == '13') {
#                         var url = $(this).parent().find('a').attr('href');
#                         var keyword = $("#keyword").val();
#                         if (keyword != '') {
#                             location.href = url+'?' + keyword_param + '=' + keyword;
#                         }
#                     }
#                 })
#                 $('.c-searchBox__search').click(function() {
#                     var url = $(this).attr('href');
#                     var keyword = $(this).parent().find('#keyword').val();
#                     if (keyword != '') {
#                         location.href = url+'?q=' + keyword;
#                     } else {
#                         location.href = url;
#                     }
#                     return false;
#                 })
#
#                 $('#market_search').click(function() {
#                     var url = $(this).attr('href');
#                     var keyword = $(this).parent().find('#keyword').val();
#                     if (keyword != '') {
#                         location.href = url+'?k=' + keyword;
#                     } else {
#                         location.href = url;
#                     }
#                     return false;
#                 });
#
#                 $(".menu_imp_hover").mouseover(function() {
#                     var ad_arr = [];
#                     ad_arr.push($(this).parent().find('li > a').first().attr('data-aid'));
#                     if (ad_arr.length > 0) {
#                         var post_obj = {
#                             'ads' : ad_arr,
#                         }
#                         $.post('/ajax/public/ad_imp.php', post_obj, function(result) {
#                         });
#                     }
#                 });
#
#                 $(".menu_target").click(function() {
#                     window.open('/adredir.php?id='+$(this).attr('data-aid'), '_blank');
#                 })
#
#                 $(".theme").click(function() {
#                     var theme = $(this).attr("date-theme");
#                     if (theme == 'w' || theme == 'd') {
#                         if (theme == "w") {
#                             $('link[href="https://attach2.mobile01.com/css/main-set-dark.css?t=1577635200"]').remove();
#                             $('link[href="https://attach2.mobile01.com/css/main-dark.css?t=1577635200"]').remove();
#                             $("article img.lazy, .l-tab__container img.lazy").each(function() {
#                                 var that = $(this);
#                                 var srccontent = that.attr("src");
#                                 if (typeof(srccontent) != 'undefined') {
#                                     srccontent.replace(/\/\/attach2\.mobile01\.com\/images\/emotions\/dark\/(.*?).gif/ig, function(matched, p1) {
#                                         that.attr("src", '//attach2.mobile01.com/images/emotions/'+p1+'.gif');
#                                         that.attr("data-src", '//attach2.mobile01.com/images/emotions/'+p1+'.gif');
#                                     });
#                                 }
#                             });
#                         }
#
#                         if (theme == "d") {
#                             $("<link/>", {rel:"stylesheet",type:"text/css",href: "https://attach2.mobile01.com/css/main-set-dark.css?t=1577635200"}).appendTo("head");
#                             $("article img.lazy, .l-tab__container img.lazy").each(function() {
#                                 var that = $(this);
#                                 var srccontent = that.attr("src");
#                                 if (typeof(srccontent) != 'undefined') {
#                                     srccontent.replace(/\/\/attach2\.mobile01\.com\/images\/emotions\/(?!.*dark\/)(.*?).gif/ig, function(matched, p1) {
#                                         that.attr("src", '//attach2.mobile01.com/images/emotions/dark/'+p1+'.gif');
#                                         that.attr("data-src", '//attach2.mobile01.com/images/emotions/dark/'+p1+'.gif');
#                                     });
#                                 }
#                             });
#                         }
#
#                         var d = new Date();
#                         var expires = new Date(2038, 1, 1);
#                         d.setTime(expires.getTime());
#
#                         //確認有無登入
#                         if ($.cookie("loginstat") == 1 && $.cookie("logintheme") != theme) { //有登入
#                             var post_obj = {
#                                 'mode'   : "theme",
#                                 'colorMode'   : theme
#                             }
#                             $.post("/ajax/account/update_user_setting.php", post_obj);
#
#                             d.setTime(d.getTime() + (30*24*60*60*1000));
#                             document.cookie = "logintheme=" + theme + ";expires=" + d.toUTCString() + ";domain=.mobile01.com;samesite=Strict;";
#                             document.cookie = "theme=" + theme + ";expires=" + d.toUTCString() + ";domain=.mobile01.com;samesite=Strict;";
#                         } else {
#                             if ($.cookie("theme") != undefined) {
#                                 document.cookie = "theme=" + theme + ";expires=" + d.toUTCString() + ";domain=.mobile01.com;samesite=Strict;";
#                             }
#                         }
#                     }
#                 })
#             });
#
#
#
#                         //Cookie提示bar
#             if ($.cookie("theme") == undefined && $.cookie("loginstat") == undefined) {
#                 $(".fixedtop").slideDown("slow");
#             }
#
#             $(".cookiebutton").click(function() {
#                 $(".fixedtop").hide();
#                 var theme = 'w';
#                 if (window.matchMedia && window.matchMedia('(prefers-color-scheme: dark)').matches) {
#                     theme = 'd';
#                 }
#
#                 var d = new Date();
#                 var expires = new Date(2038, 1, 1);
#                 d.setTime(expires.getTime());
#                 document.cookie = "theme=" + theme + ";expires=" + d.toUTCString() + ";domain=.mobile01.com;samesite=Strict;";
#             });
#
#             if ($.cookie('buuid-0') == undefined || $.cookie('buuid-0') != 'b81f16f6b736cfeab9c1b8ae3d7e0e6f') {
#                 var ajax_url = "ajax/bluekai/fetchuuid.php";
#                 $.ajax({
#                     url: ajax_url,
#                     type: 'POST',
#                     cache: false,
#                     dataType: 'json'
#                 });
#             }
#
#             if ($.cookie('bucate-0') == undefined) {
#                 var ajax_url = "ajax/bluekai/fetch_user_categories.php";
#                 $.ajax({
#                     url: ajax_url,
#                     type: 'POST',
#                     cache: false,
#                     dataType: 'json'
#                 });
#             }
#
#             function ad_fixed() {
#                 if($('.ad_fixed').length){
#                     if ($('[data-fixed-target="docking"]').hasClass("is-docking")) {
#                         var fixed_top = $('.l-header__nav').outerHeight(true) + $('[data-fixed-target="docking"].is-docking').outerHeight(true);
#                     } else {
#                         var fixed_top = $('.l-header__nav').outerHeight(true);
#                     }
#
#                     $('.ad_fixed').css('top', '' + fixed_top + 'px');
#                 }
#             }
#             addLoadEvent(ad_fixed);
#
#             function addLoadEvent(fun) {
#                 var oldonload = window.onload;
#                 if (typeof window.onload != 'function') {
#                     window.onload = fun;
#                 } else {
#                     window.onload = function() {
#                         if (oldonload) {
#                             oldonload();
#                         }
#                         fun();
#                     }
#                 }
#             }
#
#             function addMenu() {
#                 if (!(/分區首頁/i.test($(this).children().html()))) {
#                     var isTablet = (/(ipad|tablet|(android(?!.*mobile))|(windows(?!.*phone)(.*touch))|kindle|playbook|silk|(puffin(?!.*(IP|AP|WP))))/.test(navigator.userAgent.toLowerCase()));
#                     if (isTablet) {
#                         var url_name = $(this).parent().children().html();
#                         var url = $(this).parent().children().attr('href');
#                         $(this).prepend('<li><a class="c-index" href="'+url+'">' + url_name + '分區首頁</a></li>');
#                     }
#                 }
#             }
# </script>
# <script src="https://attach2.mobile01.com/js/mobile/public/mobile_pagenation.js">
# </script>
# <script>
#  if (document.body.clientWidth < 1600) {
#         $( "div" ).remove( ".ad-double" );
#     }
#
#     $(document).ready(function() {
#         var page_url = $("link[rel='canonical']").attr("href");
#         let mainURL = new URL(page_url);
#         var sub_url = mainURL.pathname;
#         sub_url = sub_url.replace('/', '');
#         var forum_id = mainURL.searchParams.getAll('f');
#         if (forum_id != '') {
#             sub_url = sub_url + '?f=' + forum_id;
#         } else {
#             sub_url = sub_url;
#         }
#         $('ul.c-filter li a[href="'+sub_url+'"]').addClass('c-iconLink--gn');
#
#         $('#sort').on("change", function() {
#             var url = 'topiclist.php?f=689';
#             if ($(this).val() != 0) {
#                 if (sub_url == 'sitemanage.php') {
#                     location.href = url+'?sort='+$(this).val();
#                 } else {
#                     location.href = url+'&sort='+$(this).val();
#                 }
#             } else {
#                 location.href = url;
#             }
#         });
#     });
# </script>
# <script src="https://attach2.mobile01.com/js/lazyload/intersection-observer.js">
# </script>
# <script src="https://attach2.mobile01.com/js/lazyload/lazyload.min.js">
# </script>
# <script>
#  $(function() {
#                 var lazyLoadInstance = new LazyLoad({
#                     elements_selector: ".lazy"
#                 });
#
#                 if (lazyLoadInstance) {
#                     lazyLoadInstance.update();
#                 }
#             });
# </script>
# <script defer="" src="https://www.gstatic.com/firebasejs/7.2.1/firebase-app.js">
# </script>
# <script defer="" src="https://www.gstatic.com/firebasejs/7.2.1/firebase-messaging.js">
# </script>
# <script defer="" src="js/firebase/init-firebase.js">
# </script>
# <script defer="" src="js/firebase/fcm.js?t=1586759400">
# </script>
# <!-- Begin ID Swap Tag-->
# <img height="1" src="https://stags.bluekai.com/site/84756?limit=0&amp;id=92093270-8083-11ea-bb57-3115b9907a00" width="1">
#  <!-- End ID Swap Tag-->
# </img>

# %%
# 所有的超連結
a_tags = soup.find_all("div")
a_tags = soup.find_all("a")
a_tags
# Out:
# [<a class="c-link c-link--gn" href="https://www.mobile01.com/privacy.php" role="button" target="_blank">了解隱私權條款</a>,
#  <a href="/">
#  <picture>
#  <!--[if IE 9]><video style="display: none;"><![endif]-->
#  <source media="(min-resolution: 1.3dppx), (-webkit-min-device-pixel-ratio: 3)" srcset="https://attach2.mobile01.com/images/logo/logo_3x.png"/>
#  <source media="(min-resolution: 1.2dppx), (-webkit-min-device-pixel-ratio: 2)" srcset="https://attach2.mobile01.com/images/logo/logo_2x.png"/>
#  <!--[if IE 9]></video><![endif]-->
#  <img alt="Mobile01" class="o-logo" srcset="https://attach2.mobile01.com/images/logo/logo.png"/>
#  </picture>
#  </a>,
#  <a class="c-group__title" data-group-trigger="group" href="/">討論群組</a>,
#  <a class="c-group__link" href="/marketindex.php">小惡魔市集</a>,
#  <a class="c-group__link" href="/tourindex.php">悅遊日本</a>,
#  <a class="c-group__link" href="/specialevent.php">活動報導</a>,
#  <a class="c-searchBox__search" href="/googlesearch.php"></a>,
#  <a class="c-login" href="/login.php?link=%2Ftopiclist.php%3Ff%3D689">登入/註冊</a>,
#  <a class="c-menuLv1__name" data-menu="lv1" href="/">首頁</a>,
#  <a href="/sitemap.php">討論區</a>,
#  <a href="/search.php">站內搜尋</a>,
#  <a href="/newslist.php">本站新聞</a>,
#  <a href="/articles.php">精選文章</a>,
#  <a href="/hottopics.php">熱門文章</a>,
#  <a href="/newtopics.php">最新文章</a>,
#  <a href="/recommendarticle.php">好文英雄</a>,
#  <a href="/youtubevideo.php">影片專區</a>,
#  <a href="/topicactivity.php">站上活動</a>,
#  <a href="/apps.php">APP下載</a>,
#  <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id=4">手機</a>,
#  <a href="/forumtopic.php?c=16">手機綜合討論區</a>,
#  <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=16&amp;s=20">Android</a>,
#  <a href="javascript:void(0);">台灣品牌</a>,
#  <a href="/topiclist.php?f=564">Acer</a>,
#  <a href="/topiclist.php?f=588">Asus</a>,
#  <a href="/topiclist.php?f=624">GSmart</a>,
#  <a href="/topiclist.php?f=566">HTC</a>,
#  <a href="/topiclist.php?f=203">InFocus</a>,
#  <a href="javascript:void(0);">日韓品牌</a>,
#  <a href="/topiclist.php?f=581">LG</a>,
#  <a href="/topiclist.php?f=568">SAMSUNG</a>,
#  <a href="/topiclist.php?f=748">Sharp</a>,
#  <a href="/topiclist.php?f=569">Sony / SE</a>,
#  <a href="javascript:void(0);">歐美品牌</a>,
#  <a href="/topiclist.php?f=722">BlackBerry</a>,
#  <a href="/topiclist.php?f=565">Google</a>,
#  <a href="/topiclist.php?f=567">MOTOROLA</a>,
#  <a href="/topiclist.php?f=742">Nokia</a>,
#  <a href="javascript:void(0);">中國品牌</a>,
#  <a href="/topiclist.php?f=629">Huawei</a>,
#  <a href="/topiclist.php?f=689">OPPO</a>,
#  <a href="/topiclist.php?f=749">SUGAR</a>,
#  <a href="/topiclist.php?f=754">vivo</a>,
#  <a href="/topiclist.php?f=634">小米手機</a>,
#  <a href="/topiclist.php?f=678">酷派</a>,
#  <a href="/topiclist.php?f=677">中興</a>,
#  <a href="/topiclist.php?f=679">聯想</a>,
#  <a href="/topiclist.php?f=586">其他品牌</a>,
#  <a href="/topiclist.php?f=423">軟體分享</a>,
#  <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=16&amp;s=21">BlackBerry</a>,
#  <a href="/topiclist.php?f=384">BlackBerry</a>,
#  <a href="/topiclist.php?f=680">軟體分享</a>,
#  <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=16&amp;s=23">Symbian</a>,
#  <a href="/topiclist.php?f=571">NOKIA</a>,
#  <a href="/topiclist.php?f=572">Samsung</a>,
#  <a href="/topiclist.php?f=573">Sony Ericsson</a>,
#  <a href="/topiclist.php?f=681">其他品牌</a>,
#  <a href="/topiclist.php?f=574">軟體分享</a>,
#  <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=16&amp;s
a>,
#  <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=7">顯示設備</a>,
#  <a href="/topiclist.php?f=298">顯示卡</a>,
#  <a href="/topiclist.php?f=350">電腦螢幕</a>,
#  <a href="/topiclist.php?f=496">電視卡盒</a>,
#  <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=8">電腦週邊</a>,
#  <a href="/topiclist.php?f=116">其他電腦週邊</a>,
#  <a href="/topiclist.php?f=351">鍵盤與手寫板</a>,
#  <a href="/topiclist.php?f=497">滑鼠與鍵鼠組</a>,
#  <a href="/topiclist.php?f=498">噴墨印表機</a>,
#  <a href="/topiclist.php?f=499">雷射印表機</a>,
#  <a href="/topiclist.php?f=500">音效裝置</a>,
#  <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=9">機殼散熱</a>,
#  <a href="/topiclist.php?f=299">機殼</a>,
#  <a href="/topiclist.php?f=501">電源供應器</a>,
#  <a href="/topiclist.php?f=502">散熱器</a>,
#  <a href="/topiclist.php?f=503">其他電源設備</a>,
#  <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=10">網路產品</a>,
#  <a href="/topiclist.php?f=110">基地台與分享器</a>,
#  <a href="/topiclist.php?f=504">網路卡</a>,
#  <a href="/topiclist.php?f=505">網路視訊與電話</a>,
#  <a href="/topiclist.php?f=506">網站與網頁技術</a>,
#  <a href="/topiclist.php?f=507">其他網路設備與技術</a>,
#  <a class="c-menuLv2__link c-menuLv2__link--child" data-menu="lv2" href="/forumtopic.php?c=17&amp;s=11">電腦軟體</a>,
#  <a href="/topiclist.php?f=300">作業系統</a>,
#  <a href="/topiclist.php?f=508">電腦安全</a>,
#  <a href="/topiclist.php?f=509">影像處理</a>,
#  <a href="/topiclist.php?f=510">影片播放與轉檔</a>,
#  <a href="/topiclist.php?f=511">文書處理</a>,
#  <a href="/topiclist.php?f=512">其他應用軟體</a>,
#  <a href="/topiclist.php?f=513">品牌電腦與準系統</a>,
#  <a href="/topiclist.php?f=174">自組電腦分享</a>,
#  <a href="/topiclist.php?f=514">其他電腦綜合討論</a>,
#  <a href="/topiclist.php?f=396">電腦組裝訪價消費分享</a>,
#  <a href="/topiclist.php?f=359">Google服務分享</a>,
#  <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id=15">蘋果</a>,
#  <a href="/forumtopic.php?c=30">蘋果綜合討論區</a>,
#  <a href="javascript:void(0);">蘋果軟體綜合</a>,
#  <a href="/topiclist.php?f=482">蘋果軟體</a>,
#  <a href="/topiclist.php?f=626">iPad 軟體</a>,
#  <a href="/topiclist.php?f=627">iPhone 軟體</a>,
#  <a href="/topiclist.php?f=563">iPad</a>,
#  <a href="/topiclist.php?f=383">iPhone</a>,
#  <a href="/topiclist.php?f=479">iPod</a>,
#  <a href="/topiclist.php?f=591">iOS Jailbreak</a>,
#  <a href="/topiclist.php?f=704">Apple TV</a>,
#  <a href="/topiclist.php?f=470">Apple Watch</a>,
#  <a href="/topiclist.php?f=480">Mac桌上型電腦</a>,
#  <a href="/topiclist.php?f=481">Mac筆記型電腦</a>,
#  <a href="/topiclist.php?f=177">蘋果週邊綜合</a>,
#  <a href="/topiclist.php?f=483">蘋果裝置消費經驗分享</a>,
#  <a class="c-menuLv1__name" data-menu="lv1" href="/category.php?id
a>,
#  <a class="c-menuLv1__name" data-menu="lv1" href="/marketindex.php">市集</a>,
#  <a class="c-menuLv1__name" data-menu="lv1" href="/tourindex.php">悅遊日本</a>,
#  <a class="c-link" href="index.php">
#                   首頁
#              </a>,
#  <a class="c-link" href="forumtopic.php?c=16">
#                   手機
#              </a>,
#  <a class="c-link" href="forumtopic.php?c=16&amp;s=20">
#                   Android
#              </a>,
#  <a class="c-link" href="topiclist.php?f=689">
#                   OPPO
#              </a>,
#  <a class="c-iconLink c-iconLink--gn" href="/rss/topiclist689.xml" target="_blank">
#  <input id="toolSubscribe" type="checkbox"/>
#  <div class="c-tool__icon c-tool__icon--subscribeGn"></div>
#  <span class="o-fSubMini">訂閱討論區</span>
#  </a>,
#  <a class="c-iconLink c-iconLink--gn" href="marketcommoditylist.php?f=689">
#  <i class="c-icon c-icon--btnShopGn"></i>
#  <span class="o-fSubMini">商品買賣</span>
#  </a>,
#  <a class="c-link" href="forumlist.php?f=16">分區列表</a>,
#  <a class="c-link" href="topiclist.php?f=203">InFocus</a>,
#  <a class="c-link" href="topiclist.php?f=423">Android軟體分享</a>,
#  <a class="c-link" href="topiclist.php?f=564">Acer</a>,
#  <a class="c-link" href="topiclist.php?f=565">Google</a>,
#  <a class="c-link" href="topiclist.php?f=566">HTC</a>,
#  <a class="c-link" href="topiclist.php?f=567">MOTOROLA</a>,
#  <a class="c-link" href="topiclist.php?f=568">SAMSUNG</a>,
#  <a class="c-link" href="topiclist.php?f=569">Sony / SE</a>,
#  <a class="c-link" href="topiclist.php?f=581">LG</a>,
#  <a class="c-link" href="topiclist.php?f=586">Android其他品牌</a>,
#  <a class="c-link" href="topiclist.php?f=588">Asus</a>,
#  <a class="c-link" href="topiclist.php?f=624">GSmart</a>,
#  <a class="c-link" href="topiclist.php?f=629">Huawei</a>,
#  <a class="c-link" href="topiclist.php?f=634">小米手機</a>,
#  <a class="c-link" href="topiclist.php?f=677">中興</a>,
#  <a class="c-link" href="topiclist.php?f=678">酷派</a>,
#  <a class="c-link" href="topiclist.php?f=679">聯想</a>,
#  <a class="c-link" href="topiclist.php?f=689">OPPO</a>,
#  <a class="c-link" href="topiclist.php?f=722">BlackBerry</a>,
#  <a class="c-link" href="topiclist.php?f=742">Nokia</a>,
#  <a class="c-link" href="topiclist.php?f=748">Sharp</a>,
#  <a class="c-link" href="topiclist.php?f=749">SUGAR</a>,
#  <a class="c-link" href="topiclist.php?f=754">vivo</a>,
#  <a class="c-iconLink" href="/articles.php?c=16&amp;s=20&amp;f=689">
#  <i class="c-icon c-icon--min c-icon--btnPlusGy"></i>
#  <span>看更多</span>
#  </a>,
#  <a class="c-articleCard c-articleCard--small" href="topicdetail.php?f=689&amp;t=6052702">
#  <div class="c-articleCard__thumbnail">
#  <img alt="" class="lazy" data-src="//attach.mobile01.com/image/news/e7a8ca2b894c4381024277db2a20f181.jpg"/>
#  </div>
#  <div class="c-articleCard__desc">
#  <div class="l-articleCardDesc">
#                          OPPO Find X2 Pro / Samsung S20 Ultra 相機比較：實用與浪漫的思辨！
#                      </div>
#  </div>
#  </a>,
#  <a class="c-articleCard c-articleCard--small" href="topicdetail.php?f=689&amp;t=6049573">
#  <div class="c-articleCard__thumbnail">
#  <img alt="" class="lazy" data-src="//attach.mobile01.com/image/news/b585143c1f251b876079dd2d632ec369.jpg"/>
#  </div>
#  <div class="c-articleCard__desc">
#  <div class="l-articleCardDesc">
#                          OPPO Find X2 Pro 不耍花招的「質樸」高材生
#                      </div>
#  </div>
#  </a>,
#  <a class="c-articleCard c-articleCard--small" href="topicdetail.php?f=689&amp;t=6011051">
#  <div class="c-articleCard__thumbnail">
#  <img alt="" class="lazy" data-src="//attach.mobile01.com/image/news/b14b4447abb071f7e505b1d5452ea0e2.jpg"/>
#  </div>
#  <div class="c-articleCard__desc">
#  <div class="l-articleCardDesc">
#                          OPPO A5 / A9 2020 體驗：四鏡頭兼具大電量、性價比仍感小可惜
#                      </div>
#  </div>
#  </a>,
#  <a class="c-articleCard c-articleCard--small" href="adredir.php?id=77047" rel="sponsored" target="_blank">
#  <div class="c-articleCard__thumbnail">
#  <img alt="" class="lazy" data-src="https://attach.mobile01.com/image/mod_ad/mobile01-396d509eccd3fe771b0f1e7d002391a6.jpg"/>
#  </div>
#  <div class="c-articleCard__desc">
#  <div class="l-articleCardDesc">
#  <span class="o-hashtag is-mini is-soldOut">贊助</span> 空汙與健康已經密不可分，LG PuriCare 360°空氣清淨機主動出擊降低室內過敏原
#                      </div>
#  </div>
#  </a>,
#  <a class="c-articleCard c-articleCard--small" href="adredir.php?id=77060" rel="sponsored" target="_blank">
#  <div class="c-articleCard__thumbnail">
#  <img alt="" class="lazy" data-src="https://attach.mobile01.com/image/mod_ad/mobile01-472a7c93289de61697ef0e31d17688cd.jpg"/>
#  </div>
#  <div class="c-articleCard__desc">
#  <div class="l-articleCardDesc">
#  <span class="o-hashtag is-mini is-soldOut">贊助</span> 溫暖人心的節日，母親節BOSE把最動聽的，獻給媽媽！
#                      </div>
#  </div>
#  </a>,
#  <a class="c-pagination" data-page="1" href="/topiclist.php?f=689">1</a>,
#  <a class="c-pagination" data-page="2" href="/topiclist.php?f=689&amp;p=2">2</a>,
#  <a class="c-pagination" data-page="3" href="/topiclist.php?f=689&amp;p=3">3</a>,
#  <a class="c-pagination" data-page="4" href="/topiclist.php?f=689&amp;p=4">4</a>,
#  <a class="c-pagination" data-page="5" href="/topiclist.php?f=689&amp;p=5">5</a>,
#  <a class="c-pagination c-pagination--next" data-page="2" href="/topiclist.php?f=689&amp;p=2"></a>,
#  <a class="c-pagination" data-page="151" href="/topiclist.php?f=689&amp;p=151">151</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6071550">Reno 10x (CPH1919) 印度已可OTA 至 Android 10</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6071550">aasuetw</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6071550&amp;p=1#77237387">aasuetw</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6071311">oppo耳機折扣碼現折250</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6071311">失戀失戀唷</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6071311&amp;p=1#77232940">失戀失戀唷</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6069864">有 find x2 pro台灣上市的消息嗎？</a>,
#  <a href="topicdetail.php?f=689&amp;t=6069864&amp;p=2">2</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6069864">楊過1983</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6069864&amp;p=2#77232562">小顯</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6071052">realme 3 Pro和5 Pro手機殼能通用嗎？</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6071052">rick1324</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6071052&amp;p=1#77232480">clarkwatch</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6061515">請益：realmeXT color OS 更新android10後，是否容易變慢？</a>,
#  <a href="topicdetail.php?f=689&amp;t=6061515&amp;p=2">2</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6061515">akioMe</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6061515&amp;p=2#77231527">pmp7589</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6067630">為何OPPO Reno 10 倍變焦版, 市面上缺貨啊?</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6067630">superparis</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6067630&amp;p=1#77230609">KAWAINE</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6057628">台版 realme XT 更新 Android 10</a>,
#  <a href="topicdetail.php?f=689&amp;t=6057628&amp;p=10">10</a>,
#  <a href="topicdetail.php?f=689&amp;t=6057628&amp;p=11">11</a>,
#  <a href="topicdetail.php?f=689&amp;t=6057628&amp;p=12">12</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6057628">insu36</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6057628&amp;p=12#77229891">WuYuJheng</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=
a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=5934118">iepindo19</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=5934118&amp;p=41#77171861">clarkwatch</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6062969">Oppo vs iphone</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6062969">hebe19920502</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6062969&amp;p=1#77170339">流浪雙飛</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=5950459">請問，OPPO Reno 2 玩傳說對決跟絕地求生會卡頓嗎?</a>,
#  <a href="topicdetail.php?f=689&amp;t=5950459&amp;p=2">2</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=5950459">王安唷</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=5950459&amp;p=2#77169798">a38704415</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6062943">realme 3 Pro 開啟VOLTE後聲音超小聲?</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6062943">s700814</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6062943&amp;p=1#77163353">rick1324</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6064294">中國地區”Reno系列”，“R17系列”即將升級ColorOS 7</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6064294">孫建平</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=6064294&amp;p=1#77163057">孫建平</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=5977767">12月中了台灣還是不上市，該是來分享realme X2 Pro心得(109.4.9起已可更新至Android 10、realme ui 1.0)</a>,
#  <a href="topicdetail.php?f=689&amp;t=5977767&amp;p=12">12</a>,
#  <a href="topicdetail.php?f=689&amp;t=5977767&amp;p=13">13</a>,
#  <a href="topicdetail.php?f=689&amp;t=5977767&amp;p=14">14</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=5977767">unwm</a>,
#  <a class="c-link u-ellipsis" href="topicdetail.php?f=689&amp;t=5977767&amp;p=14#77157003">unwm</a>,
#  <a class="c-pagination" data-page="1" href="/topiclist.php?f=689">1</a>,
#  <a class="c-pagination" data-page="2" href="/topiclist.php?f=689&amp;p=2">2</a>,
#  <a class="c-pagination" data-page="3" href="/topiclist.php?f=689&amp;p=3">3</a>,
#  <a class="c-pagination" data-page="4" href="/topiclist.php?f=689&amp;p=4">4</a>,
#  <a class="c-pagination" data-page="5" href="/topiclist.php?f=689&amp;p=5">5</a>,
#  <a class="c-pagination c-pagination--next" data-page="2" href="/topiclist.php?f=689&amp;p=2"></a>,
#  <a class="c-pagination" data-page="151" href="/topiclist.php?f=689&amp;p=151">151</a>,
#  <a class="c-link" href="index.php">
#                   首頁
#              </a>,
#  <a class="c-link" href="forumtopic.php?c=16">
#                   手機
#              </a>,
#  <a class="c-link" href="forumtopic.php?c=16&amp;s=20">
#                   Android
#              </a>,
#  <a class="c-link" href="topiclist.php?f=689">
#                   OPPO
#              </a>,
#  <a class="c-btn c-btn--primary" href="">我要發佈</a>,
#  <a class="c-articleCard" href="topicdetail.php?f=689&amp;t=6068401">
#  <div class="c-articleCard__thumbnail">
#  <img alt="" class="lazy" data-src="//attach.mobile01.com/image/news/0160867b2bd28bf00d73c4c4b856958a.png"/>
#  </div>
#  <div class="c-articleCard__desc">
#  <div class="l-articleCardDesc">
#                  OPPO Ace2電競旗艦揭曉 不僅輕薄、還有40W無線充電！
#              </div>
#  </div>
#  </a>,
#  <a class="c-articleCard" href="topicdetail.php?f=568&amp;t=6065233">
#  <div class="c-articleCard__thumbnail">
#  <img alt="" class="lazy" data-src="//attach.mobile01.com/image/news/09192aa0b0e9df27981d9860197907ea.jpg"/>
#  </div>
#  <div class="c-articleCard__desc">
#  <div class="l-articleCardDesc">
#                  比較安心～ 三星即日起推出Galaxy裝置的紫外線清潔服務
#              </div>
#  </div>
#  </a>,
#  <a class="c-link" href="promotionlist.php" target="_blank">小惡魔廣編特輯</a>,
#  <a class="c-articleCard" href="adredir.php?id=77044" rel="sponsored" target="blank">
#  <div class="c-articleCard__thumbnail">
#  <img alt="" class="lazy" data-src="https://attach.mobile01.com/image/mod_ad/mobile01-dad799617c33df87747fa5081df27aa7.jpg"/>
#  </div>
#  <div class="c-articleCard__desc">
#  <div class="l-articleCardDesc">
#                  居家抗敏四大神器，全面擊退家中過敏原
#              </div>
#  </div>
#  </a>,
#  <a class="c-articleCard" href="adredir.php?id=77050" rel="sponsored" target="blank">
#  <div class="c-articleCard__thumbnail">
#  <img alt="" class="lazy" data-src="https://attach.mobile01.com/image/mod_ad/mobile01-8939b36cbad978f80d1d7584d9d629f7.jpg"/>
#  </div>
#  <div class="c-articleCard__desc">
#  <div class="l-articleCardDesc">
#                  謝謝你，好文英雄！Mobile01網友好文獎勵系統上線！
#              </div>
#  </div>
#  </a>,
#  <a class="c-link" href="/vipapply.php">加入VIP會員</a>,
#  <a class="c-link" href="/forumtopic.php?c=9">站務回報</a>,
#  <a class="c-link" href="/downloads.php">檔案下載</a>,
#  <a class="c-link" href="/faq.php">常問問題集</a>,
#  <a class="c-link" href="/tos.php">服務條款</a>,
#  <a class="c-link" href="/privacy.php">隱私權政策</a>,
#  <a class="c-link" href="/proposal.php">合作與廣告</a>,
#  <a class="c-link" href="/contactus.php">聯絡我們</a>,
#  <a class="c-link" href="/jobs.php">工作機會</a>,
#  <a class="c-link" href="/memberlist.php">線上會員</a>,
#  <a class="c-link" href="/specialevent.php">活動與報導</a>,
#  <a class="c-link" href="/sitemap.php">網站地圖</a>,
#  <a href="/rss.php"><img alt="rss" src="https://attach2.mobile01.com/images/icons/footer/footer-rss.svg"/></a>,
#  <a href="/"><img alt="home" src="https://attach2.mobile01.com/images/icons/footer/footer-home.svg"/></a>,
#  <a href="https://www.facebook.com/TheMobile01" rel="nofollow noopener noreferrer" target="_blank">
#  <img alt="Mobile01 facebook" height="28" src="https://attach2.mobile01.com/images/icons/social/facebook-footer.svg" width="28"/>
#  </a>,
#  <a href="https://twitter.com/Mobile01Service" rel="nofollow noopener noreferrer" target="_blank">
#  <img alt="Mobile01 twitter" height="32" src="https://attach2.mobile01.com/images/icons/social/twitter-footer.svg" width="32"/>
#  </a>,
#  <a href="https://www.youtube.com/channel/UCUblDAHVdNEMhQ39ahmPFxA" rel="nofollow noopener noreferrer" target="_blank">
#  <img alt="Mobile01 youtube" height="32" src="https://attach2.mobile01.com/images/icons/social/youtube-footer.svg" width="32"/>
#  </a>,
#  <a href="https://apps.apple.com/tw/app/mobile01/id444909583" rel="nofollow noopener noreferrer" target="_blank">
#  <img alt="Mobile01 iOS app" height="32" src="https://attach2.mobile01.com/images/icons/social/apple-footer.svg" width="32"/>
#  </a>,
#  <a href="https://play.google.com/store/apps/details?id=com.mobile01.android.forum&amp;hl=zh_TW" rel="nofollow noopener noreferrer" target="_blank">
#  <img alt="Mobile01 Android app" height="32" src="https://attach2.mobile01.com/images/icons/social/android-footer.svg" width="32"/>
#  </a>,
#  <a class="theme" date-theme="w" href="javascript:void(0);">
#  <img alt="light mode" height="32" src="https://attach2.mobile01.com/images/icons/tools/tool-day.svg" width="32"/>
#  </a>,
#  <a class="theme" date-theme="d" href="javascript:void(0);">
#  <img alt="dark mode" height="32" src="https://attach2.mobile01.com/images/icons/tools/tool-dark.svg" width="32"/>
#  </a>]

# %%
for tag in a_tags:
  # 輸出超連結的文字
  print(tag.string)
